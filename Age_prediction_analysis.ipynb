# %% [markdown]
# **Step 1: Import Libraries and Load the Data**

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/dataset/NHANES_age_prediction.csv")

df.shape
# Out:
# (2278, 10)

# %% [markdown]
# #Feature          Description
# ##RIAGENDR        Gender (1=Male, 2=Female)
# ##PAQ605          Physical activity level
# ##BMXBMI          Body Mass Index
# ##LBXGLU          Fasting glucose (mg/dL)
# ##DIQ010          Doctor told you have diabetes (1=Yes, 2=No)
# ##LBXGLT          Glucose tolerance test
# ##LBXIN.          Insulin level
# ##age_group       Target (Adult vs. Senior)

# %%
df.head()
# Out:
#       SEQN age_group  RIDAGEYR  RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  \
# 0  73564.0     Adult      61.0       2.0     2.0    35.7   110.0     2.0
# 1  73568.0     Adult      26.0       2.0     2.0    20.3    89.0     2.0
# 2  73576.0     Adult      16.0       1.0     2.0    23.2    89.0     2.0
# 3  73577.0     Adult      32.0       1.0     2.0    28.9   104.0     2.0
# 4  73580.0     Adult      38.0       2.0     1.0    35.9   103.0     2.0
#
#    LBXGLT  LBXIN
# 0   150.0  14.91
# 1    80.0   3.85
# 2    68.0   6.14
# 3    84.0  16.15
# 4    81.0  10.92

# %%
df.tail()
# Out:
#          SEQN age_group  RIDAGEYR  RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  \
# 2273  83711.0     Adult      38.0       2.0     2.0    33.5   100.0     2.0
# 2274  83712.0     Adult      61.0       1.0     2.0    30.0    93.0     2.0
# 2275  83713.0     Adult      34.0       1.0     2.0    23.7   103.0     2.0
# 2276  83718.0     Adult      60.0       2.0     2.0    27.4    90.0     2.0
# 2277  83727.0     Adult      26.0       1.0     2.0    24.5   108.0     2.0
#
#       LBXGLT  LBXIN
# 2273    73.0   6.53
# 2274   208.0  13.02
# 2275   124.0  21.41
# 2276   108.0   4.99
# 2277   108.0   3.76

# %% [markdown]
# **Step 2: Inspect Data Structure**

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of          SEQN age_group  RIDAGEYR  RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  \
# 0     73564.0     Adult      61.0       2.0     2.0    35.7   110.0     2.0
# 1     73568.0     Adult      26.0       2.0     2.0    20.3    89.0     2.0
# 2     73576.0     Adult      16.0       1.0     2.0    23.2    89.0     2.0
# 3     73577.0     Adult      32.0       1.0     2.0    28.9   104.0     2.0
# 4     73580.0     Adult      38.0       2.0     1.0    35.9   103.0     2.0
# ...       ...       ...       ...       ...     ...     ...     ...     ...
# 2273  83711.0     Adult      38.0       2.0     2.0    33.5   100.0     2.0
# 2274  83712.0     Adult      61.0       1.0     2.0    30.0    93.0     2.0
# 2275  83713.0     Adult      34.0       1.0     2.0    23.7   103.0     2.0
# 2276  83718.0     Adult      60.0       2.0     2.0    27.4    90.0     2.0
# 2277  83727.0     Adult      26.0       1.0     2.0    24.5   108.0     2.0
#
#       LBXGLT  LBXIN
# ...

# %%
df.describe()
# Out:
#                SEQN     RIDAGEYR     RIAGENDR       PAQ605       BMXBMI  \
# count   2278.000000  2278.000000  2278.000000  2278.000000  2278.000000
# mean   78691.853819    41.795874     1.511414     1.822651    27.955180
# std     2921.365151    20.156111     0.499979     0.398918     7.248962
# min    73564.000000    12.000000     1.000000     1.000000    14.500000
# 25%    76171.750000    24.000000     1.000000     2.000000    22.800000
# 50%    78749.000000    41.000000     2.000000     2.000000    26.800000
# 75%    81213.500000    58.000000     2.000000     2.000000    31.200000
# max    83727.000000    80.000000     2.000000     7.000000    70.100000
#
#             LBXGLU       DIQ010       LBXGLT        LBXIN
# count  2278.000000  2278.000000  2278.000000  2278.000000
# mean     99.553117     2.016242   114.978929    11.834794
# std      17.889834     0.185556    47.061239     9.718812
# min      63.000000     1.000000    40.000000     0.140000
# ...

# %%
print(df['age_group'].value_counts())
# Out:
# age_group
# Adult     1914
# Senior     364
# Name: count, dtype: int64

# %%
print(df['RIAGENDR'].value_counts())
# Out:
# RIAGENDR
# 2.0    1165
# 1.0    1113
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# SEQN         0
# age_group    0
# RIDAGEYR     0
# RIAGENDR     0
# PAQ605       0
# BMXBMI       0
# LBXGLU       0
# DIQ010       0
# LBXGLT       0
# LBXIN        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# SEQN         0
# age_group    0
# RIDAGEYR     0
# RIAGENDR     0
# PAQ605       0
# BMXBMI       0
# LBXGLU       0
# DIQ010       0
# LBXGLT       0
# LBXIN        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step 4: Explore Distributions**

# %%
df.hist(figsize=(15,10), bins=20)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='age_group', y='BMXBMI', data=df)
plt.title('BMI Distribution by Age Group')
plt.show()

# %%
df.drop('SEQN', axis=1, inplace=True)

# %%
df.head()
# Out:
#   age_group  RIDAGEYR  RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  LBXGLT  LBXIN
# 0     Adult      61.0       2.0     2.0    35.7   110.0     2.0   150.0  14.91
# 1     Adult      26.0       2.0     2.0    20.3    89.0     2.0    80.0   3.85
# 2     Adult      16.0       1.0     2.0    23.2    89.0     2.0    68.0   6.14
# 3     Adult      32.0       1.0     2.0    28.9   104.0     2.0    84.0  16.15
# 4     Adult      38.0       2.0     1.0    35.9   103.0     2.0    81.0  10.92

# %%
import numpy as np

# %%
for col in ['LBXGLU', 'LBXGLT', 'LBXIN', 'BMXBMI']:
  upper_limit = np.percentile(df[col], 99)
  df[col]=np.where(df[col]>upper_limit, upper_limit, df[col])

# %%
df['age_group'].value_counts(normalize=True)
# Out:
# age_group
# Adult     0.840211
# Senior    0.159789
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#           RIDAGEYR     RIAGENDR       PAQ605       BMXBMI       LBXGLU  \
# count  2278.000000  2278.000000  2278.000000  2278.000000  2278.000000
# mean     41.795874     1.511414     1.822651    27.895592    98.885426
# std      20.156111     0.499979     0.398918     7.009188    12.328563
# min      12.000000     1.000000     1.000000    14.500000    63.000000
# 25%      24.000000     1.000000     2.000000    22.800000    91.000000
# 50%      41.000000     2.000000     2.000000    26.800000    97.000000
# 75%      58.000000     2.000000     2.000000    31.200000   104.000000
# max      80.000000     2.000000     7.000000    51.146000   155.000000
#
#             DIQ010       LBXGLT        LBXIN
# count  2278.000000  2278.000000  2278.000000
# mean      2.016242   114.228850    11.698959
# std       0.185556    42.594234     8.971384
# min       1.000000    40.000000     0.140000
# 25%       2.000000    87.000000     5.860000
# 50%       2.000000   105.000000     9.040000
# ...

# %%
cols_to_plot = ['BMXBMI', 'LBXGLU', 'LBXGLT', 'LBXIN']
df[cols_to_plot].hist(figsize=(10, 8), bins=20)
plt.suptitle("Distributions After Outlier Capping")
plt.show()

sns.boxplot(x='age_group', y='BMXBMI', data=df)
plt.title("BMI by Age Group")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
import numpy as np



# 2️⃣ Encode categorical columns
label = LabelEncoder()
df['age_group'] = label.fit_transform(df['age_group'])  # Adult=0, Senior=1

# Convert RIAGENDR and DIQ010 to category codes
df['RIAGENDR'] = df['RIAGENDR'].astype('category').cat.codes
df['DIQ010'] = df['DIQ010'].astype('category').cat.codes

# 3️⃣ Define features and target
X = df.drop(['RIDAGEYR', 'age_group'], axis=1)
y = df['age_group']

# 4️⃣ Scale continuous variables
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, stratify=y, random_state=42
)

# Weighted Logistic Regression
model = LogisticRegression(class_weight='balanced', random_state=42)
model.fit(X_train, y_train)

# Evaluate
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.show()
# Out:
# Accuracy: 0.7368421052631579
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.75      0.83       383
#            1       0.34      0.67      0.45        73
#
#     accuracy                           0.74       456
#    macro avg       0.63      0.71      0.64       456
# weighted avg       0.83      0.74      0.77       456

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    random_state=42,
    class_weight='balanced',  # handles imbalance
    n_estimators=200
)

rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("\nClassification Report:\n", classification_report(y_test, y_pred_rf))

# Feature importance
import pandas as pd
feat_imp = pd.Series(rf.feature_importances_, index=X.columns)
feat_imp.sort_values().plot(kind='barh', figsize=(8, 6))
plt.title("Feature Importance (Random Forest)")
plt.show()
# Out:
# Random Forest Accuracy: 0.8399122807017544
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91       383
#            1       0.50      0.10      0.16        73
#
#     accuracy                           0.84       456
#    macro avg       0.68      0.54      0.54       456
# weighted avg       0.79      0.84      0.79       456

# %%
# ---------------------------------------------------------
# 🧩 Logistic Regression with SMOTE Oversampling
# ---------------------------------------------------------

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt

# 1️⃣ Train-test split (as before)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, stratify=y, random_state=42
)

print("Before SMOTE:", np.bincount(y_train))

# 2️⃣ Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

print("After SMOTE:", np.bincount(y_train_res))

# 3️⃣ Train Logistic Regression (no need for class_weight now)
model = LogisticRegression(random_state=42, max_iter=1000)
model.fit(X_train_res, y_train_res)

# 4️⃣ Evaluate on real test set (not oversampled)
y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]

print("\n🔹 Logistic Regression with SMOTE Results")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_proba))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# 5️⃣ Confusion Matrix
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Logistic Regression (SMOTE) Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Before SMOTE: [1531  291]
# After SMOTE: [1531 1531]
#
# 🔹 Logistic Regression with SMOTE Results
# Accuracy: 0.7368421052631579
# ROC AUC: 0.7722736864694731
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.75      0.83       383
#            1       0.34      0.66      0.44        73
#
#     accuracy                           0.74       456
#    macro avg       0.63      0.70      0.64       456
# weighted avg       0.83      0.74      0.77       456

# %%
# ---------------------------------------------------------
# 🌳 Decision Tree & ⚡ XGBoost with SMOTE
# ---------------------------------------------------------

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    accuracy_score, classification_report, confusion_matrix, roc_auc_score
)
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1️⃣ Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, stratify=y, random_state=42
)

print("Before SMOTE:", np.bincount(y_train))

# 2️⃣ Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

print("After SMOTE:", np.bincount(y_train_res))

# ---------------------------------------------------------
# 🌳 3️⃣ Decision Tree Model
# ---------------------------------------------------------
dt = DecisionTreeClassifier(
    criterion='gini',
    max_depth=6,          # limit depth to prevent overfitting
    min_samples_split=5,
    random_state=42
)
dt.fit(X_train_res, y_train_res)
y_pred_dt = dt.predict(X_test)
y_proba_dt = dt.predict_proba(X_test)[:, 1]

print("\n🌳 Decision Tree Results")
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print("ROC AUC:", roc_auc_score(y_test, y_proba_dt))
print(classification_report(y_test, y_pred_dt))

sns.heatmap(confusion_matrix(y_test, y_pred_dt), annot=True, fmt='d', cmap='Greens')
plt.title("Decision Tree Confusion Matrix")
plt.show()

# ---------------------------------------------------------
# ⚡ 4️⃣ XGBoost Model
# ---------------------------------------------------------
xgb = XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric='logloss'
)
xgb.fit(X_train_res, y_train_res)
y_pred_xgb = xgb.predict(X_test)
y_proba_xgb = xgb.predict_proba(X_test)[:, 1]

print("\n⚡ XGBoost Results")
print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("ROC AUC:", roc_auc_score(y_test, y_proba_xgb))
print(classification_report(y_test, y_pred_xgb))

sns.heatmap(confusion_matrix(y_test, y_pred_xgb), annot=True, fmt='d', cmap='Oranges')
plt.title("XGBoost Confusion Matrix")
plt.show()

# ---------------------------------------------------------
# 📊 5️⃣ Compare Model Performances
# ---------------------------------------------------------
results = pd.DataFrame({
    'Model': ['Decision Tree', 'XGBoost'],
    'Accuracy': [
        accuracy_score(y_test, y_pred_dt),
        accuracy_score(y_test, y_pred_xgb)
    ],
    'ROC AUC': [
        roc_auc_score(y_test, y_proba_dt),
        roc_auc_score(y_test, y_proba_xgb)
    ]
})

print("\n📈 Model Comparison:\n", results)
# Out:
# Before SMOTE: [1531  291]
# After SMOTE: [1531 1531]
#
# 🌳 Decision Tree Results
# Accuracy: 0.6885964912280702
# ROC AUC: 0.696752387424443
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79       383
#            1       0.28      0.60      0.38        73
#
#     accuracy                           0.69       456
#    macro avg       0.59      0.65      0.59       456
# weighted avg       0.80      0.69      0.73       456
# ⚡ XGBoost Results
# Accuracy: 0.7675438596491229
# ROC AUC: 0.7440537930541149
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86       383
#            1       0.35      0.51      0.41        73
#
#     accuracy                           0.77       456
#    macro avg       0.62      0.66      0.63       456
# weighted avg       0.81      0.77      0.78       456
# 📈 Model Comparison:
#             Model  Accuracy   ROC AUC
# ...
